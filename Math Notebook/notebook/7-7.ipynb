# %%
import math
pi = math.pi
x = []
c=1
intervals=10

#fx=14*math.sin(x)
def fx(u):
    y=14*math.sin(u)
    return(y)

def trapezoidalRule(u):
    T=(pi/10)*(1/2)*(2*u)
    return(T)

for i in range(intervals):
    x.append((i*pi)/10)
    print(f"{i}𝜋/10 = {x[i]}")
    x[i]=fx(x[i])
    print(f"\t14sin({i}𝜋/10) = {x[i]}")
print(x)

for c in range(intervals-1):
    x[c]=trapezoidalRule(x[c])
print(x)
# Out:
# 0𝜋/10 = 0.0
# 	14sin(0𝜋/10) = 0.0
# 1𝜋/10 = 0.3141592653589793
# 	14sin(1𝜋/10) = 4.326237921249263
# 2𝜋/10 = 0.6283185307179586
# 	14sin(2𝜋/10) = 8.228993532094623
# 3𝜋/10 = 0.9424777960769379
# 	14sin(3𝜋/10) = 11.326237921249264
# 4𝜋/10 = 1.2566370614359172
# 	14sin(4𝜋/10) = 13.31479122813215
# 5𝜋/10 = 1.5707963267948966
# 	14sin(5𝜋/10) = 14.0
# 6𝜋/10 = 1.8849555921538759
# 	14sin(6𝜋/10) = 13.314791228132151
# 7𝜋/10 = 2.199114857512855
# 	14sin(7𝜋/10) = 11.326237921249264
# 8𝜋/10 = 2.5132741228718345
# 	14sin(8𝜋/10) = 8.228993532094625
# 9𝜋/10 = 2.827433388230814
# 	14sin(9𝜋/10) = 4.326237921249265
# [0.0, 4.326237921249263, 8.228993532094623, 11.326237921249264, 13.31479122813215, 14.0, 13.314791228132151, 11.326237921249264, 8.228993532094625, 4.326237921249265]
# [0.0, 1.3591277271078264, 2.585214562686639, 3.558242584620682, 4.182965030638178, 4.39822971502571, 4.1829650306381785, 3.558242584620682, 2.5852145626866396, 4.326237921249265]

# %%
        
def midpoints(lowBound, topBound, interval, fx):
    M = (topBound/interval)*(fx)

def midpointEnum(u, interval):
    i=1
    for i in range(2*interval):
        if i%0!=0:
            mN=((i*pi)/(2*interval))
            mEnum+=mN

def midpointEnum(u, interval):
    mN=((i*pi)/(2*interval))

def f(u):
    y = 14*math.sin(u)
    return(y)

x=[]
mN=0
mEnum=0
u=0
interval=10

for i in range(2*intervals):
    x.append((i*pi)/(2*interval))
    print(f"{i}𝜋/20 = {x[i]}")
    x[i] = f(x[i])
    print(f"\t14sin({i}𝜋/20) = {x[i]}")
    i+=2
print(x)

# midpoints(0,math.pi, 10, fx)
# Out:
# 0𝜋/20 = 0.0
# 	14sin(0𝜋/20) = 0.0
# 1𝜋/20 = 0.15707963267948966
# 	14sin(1𝜋/20) = 2.190082510563232
# 2𝜋/20 = 0.3141592653589793
# 	14sin(2𝜋/20) = 4.326237921249263
# 3𝜋/20 = 0.47123889803846897
# 	14sin(3𝜋/20) = 6.3558669963536545
# 4𝜋/20 = 0.6283185307179586
# 	14sin(4𝜋/20) = 8.228993532094623
# 5𝜋/20 = 0.7853981633974483
# 	14sin(5𝜋/20) = 9.899494936611665
# 6𝜋/20 = 0.9424777960769379
# 	14sin(6𝜋/20) = 11.326237921249264
# 7𝜋/20 = 1.0995574287564276
# 	14sin(7𝜋/20) = 12.474091338637148
# 8𝜋/20 = 1.2566370614359172
# 	14sin(8𝜋/20) = 13.31479122813215
# 9𝜋/20 = 1.413716694115407
# 	14sin(9𝜋/20) = 13.827636768331928
# 10𝜋/20 = 1.5707963267948966
# 	14sin(10𝜋/20) = 14.0
# 11𝜋/20 = 1.727875959474386
# 	14sin(11𝜋/20) = 13.827636768331928
# 12𝜋/20 = 1.8849555921538759
# 	14sin(12𝜋/20) = 13.314791228132151
# 13𝜋/20 = 2.0420352248333655
# 	14sin(13𝜋/20) = 12.47409133863715
# 14𝜋/20 = 2.199114857512855
# 	14sin(14𝜋/20) = 11.326237921249264
# 15𝜋/20 = 2.356194490192345
# ...
